# %% [markdown]
# # Explore Zillow

# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Wrangling
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Statistical Tests
import scipy.stats as stats

# Visualizing
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
from sklearn.model_selection import learning_curve

import wrangle

# %% [markdown]
# ### Ask at least 5 questions about the data, keeping in mind that your target variable is logerror. e.g. Is logerror significantly different for properties in LA County vs Orange County vs Ventura County?
# - Los Angeles County (6037), Orange County (6059), Ventura County (6111), in California.

# %%
df, train, validate, test = wrangle.wrangle_zillow()

# %%
df.shape, train.shape, validate.shape, test.shape
# Out:
# ((41536, 25), (17320, 25), (7423, 25), (6186, 25))

# %%
train[(df.logerror > -1) & (train.logerror < 1)].logerror.hist()
# Out:
# <AxesSubplot:>

# %%
train[(train.logerror > -.5) & (train.logerror < .5)].logerror.hist()
# Out:
# <AxesSubplot:>

# %%
train[(train.logerror > -.2) & (train.logerror < .2)].logerror.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What are the logerror relationshipe for each county?

# %%
train.shape
# Out:
# (17320, 25)

# %%
train2 = train[(train.logerror > -.2) & (train.logerror < .2)]
train2.shape
# Out:
# (16397, 25)

# %%
sns.relplot(data=train2, y='taxvaluedollarcnt', x='logerror', hue='fips', height=5, aspect=2)

# %%
sns.relplot(data=train2, y='taxvaluedollarcnt', x='logerror', hue='fips', height=5, aspect=2)

# %% [markdown]
# ### Notes:
# - dense errors ranges between -.10 and .15
# - errors become more concentrated with incrased value
# - can't see differencees between fips
#
# ### RelPlot with fips set for cols

# %%
sns.relplot(data=train2, y='taxvaluedollarcnt', x='logerror', col='fips', height=8)

# %% [markdown]
# ### Notes:
# - LA: dense errors range between -.1 and .09 // larges range at lower values
# - Orange: dense errors range between -.05 and .07 // larges density range at mid-lower values
# - Ventura: dense errors range between -.03 and .05 // larges density range at mid values
#
# ### Show baxplot for logerror for counties

# %%
sns.boxplot(data=train2)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Answer those questions through a mix of statistical tests and visualizations.
